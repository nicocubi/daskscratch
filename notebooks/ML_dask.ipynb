# %% [markdown]
# # Dask and Scikit-learn

# %% [markdown]
# - chunking data
# - distributing tasks
# - aggregating results

# %% [markdown]
# ### Dask features
# - hyperparameter tuning
# - pipeline creations (preprocessing, training, evaulation are integrated)

# %%
# First create a client
from dask.distributed import Client

client = Client(n_workers=4, threads_per_worker=1, memory_limit="8GB")

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:33567' processes=4 threads=4, memory=29.80 GiB>

# %% [markdown]
# ## Loading and preprocessing the dataset

# %%
import dask.dataframe as dd
from dask_ml.model_selection import train_test_split # you have to install dask_ml

# %% [markdown]
# # Loading the dataset
# df = dd.read_csv("yellow_tripdata_2026-03.csv")
#
# # Select features and target variables
# features = ["....]
#
# # See the tutorial at https://www.udemy.com/course/master-dask-python-parallel-computing-for-data-science/learn/lecture/50652591#overview
