# %% [markdown]
# # Using lab_extension

# %%
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:45831' processes=4 threads=8, memory=7.57 GiB>

# %%
# You can create a Cluster outside of the notebook and display it here
# If you type code in the notebook, it will be executed throug this external client
# this is practical but can also be dangerous

# %%
# Run some computation
import dask.array as da

# %%
x = da.random.random((10000,10000), chunks="16MiB")
x
# Out:
# dask.array<random_sample, shape=(10000, 10000), dtype=float64, chunksize=(1448, 1448), chunktype=numpy.ndarray>

# %%
y = (x + x.T) - x.mean(axis=0)
y.sum().compute()
# Out:
# np.float64(50002647.824247226)
